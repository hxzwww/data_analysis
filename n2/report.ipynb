# %% [markdown]
# # Задача 2

# %% [markdown]
# ### Условие:
# #### 1) Понять как зависило количество просмотров от даты за данный промежуток времени.
# #### 2) Понять как были взаимосвязаны количества лайков и просмотров за данный промежуток времени.

# %%
from task_2 import YouTube
b = YouTube()
b.task2()
b.task4()

# %% [markdown]
# #### Как видно из графика, основная часть видео набирали не более 200000 просмотров. При этом видно, что в период с 14 по 18 число среднее количество просмотро монотонно росло, затем резко упало и опять начало расти.

# %%
b.task6()

# %% [markdown]
# #### При увеличении количества лайков и/или просмотров уменьшается количество подходящих видео, но если "по лайкам" эта величина практически убывает монотонно, то "по просмотрам" она имеет пиковое значение примерно на 5000-8000 просмотрах.

# %% [markdown]
# ### Вывод:
# #### 1) Так как 18 число - это суббота, становится понятно почему график выглядит именно так - люди в основном залипают в ютуб по вечерам, и именно в пятницу-субботу люди могут позволить себе лечь позже и подольше посмотреть видосы.
# #### 2) Как и следовало ожидать, существует обратная пропорциональность между количеством видео и их популярность у пользователей. Интересным релуьтатом исследования является факт того, что 5000-8000 просмотров - наиболее популярное значение. Логичным предположить, что это происходит из-за того, что это среднее количество просмотров для каналов со средним числом подписчиков, а таких каналов, очевидно, больше всего (старые каналы со старыми видосами).

# %% [markdown]
# ---

# %% [markdown]
# # Задача 3

# %% [markdown]
# ### Условие:
# #### В этой задаче нужно построить тепловую карту просмотров по дням для каждой категории видео.

# %%
from task_3 import YouTube2
c = YouTube2()
c.task1()
c.task4()
c.task5()

# %% [markdown]
# #### На графике отображена зависимость количества просмотров видео определеннной категории от даты, добавлены поля суммарных значений по дням и категориям.
# #### Для того чтобы этот график был более информативен я добавил подписи на клетках, посчитал суммарные значение на столбцах/строках, а также установил параметр vmax для более удобного визуального восприятия (vmin не добавил т.к. считаю что это бы ухудшило читаемость).

# %% [markdown]
# ### Вывод:
# #### По  полям суммарных просмотров становится видно, как и в случае 2 задачи, что 17 и 18 числа - это пятница и суббота соответственно, а так же то что пользователей больше всего интересуют развлечения и блоги, и меньше всего - путешествия и образование.
